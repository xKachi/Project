# %% [markdown]
# # Machine Learning Modeling Using SMOTE Dataset

# %%
# %%capture
# %matplotlib inline
from Exploratory_Data_Analysis import *
import pycaret
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %%
X = ds.drop("class", axis=1)
y = ds["class"]

# %% [markdown]
# ### Splitting the data into training and testing sets

# %%
### Instantiating SMOTE
sm = SMOTE(random_state=42)

### Fit SMOTE to training data
X_train_res, y_train_res = sm.fit_resample(X, y)

# %% [markdown]
# ### Printing class disribution of original and resampled data

# %%
print("Class Distribution before Resampleing: ", y.value_counts())

print("\nClass Distribution afer Resampling", y_train_res.value_counts())
# Out:
# Class Distribution before Resampleing:  class
# 1    123
# 0     32
# Name: count, dtype: int64
#
# Class Distribution afer Resampling class
# 1    123
# 0    123
# Name: count, dtype: int64

# %% [markdown]
# ### combine "X_train_res" and "y_train_res"

# %%
train_data = pd.concat([X_train_res, y_train_res], axis=1)

from pycaret.classification import *
s = setup(data=train_data, target='class', session_id=123, normalize=True)
# Out:
# <style type="text/css">
# #T_690e6_row8_col1, #T_690e6_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_690e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_690e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_690e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_690e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_690e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_690e6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_690e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_690e6_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_690e6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_690e6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_690e6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_690e6_row3_col1" class="data row3 col1" >(246, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_690e6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_690e6_row4_col1" class="data row4 col1" >(246, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_690e6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_690e6_row5_col1" class="data row5 col1" >(172, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_690e6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_690e6_row6_col1" class="data row6 col1" >(74, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_690e6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_690e6_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_690e6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_690e6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_690e6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_690e6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_690e6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_690e6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_690e6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_690e6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_690e6_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_690e6_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_690e6_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_690e6_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_690e6_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_690e6_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_690e6_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_690e6_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_690e6_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_690e6_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_690e6_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_690e6_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_690e6_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_690e6_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_690e6_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_690e6_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_690e6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_690e6_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_690e6_row20_col1" class="data row20 col1" >8833</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_1f707 th {
#   text-align: left;
# }
# #T_1f707_row0_col0, #T_1f707_row0_col2, #T_1f707_row0_col4, #T_1f707_row1_col0, #T_1f707_row1_col1, #T_1f707_row1_col3, #T_1f707_row1_col4, #T_1f707_row1_col5, #T_1f707_row1_col6, #T_1f707_row1_col7, #T_1f707_row2_col0, #T_1f707_row2_col1, #T_1f707_row2_col2, #T_1f707_row2_col3, #T_1f707_row2_col4, #T_1f707_row2_col5, #T_1f707_row2_col6, #T_1f707_row2_col7, #T_1f707_row3_col0, #T_1f707_row3_col1, #T_1f707_row3_col2, #T_1f707_row3_col3, #T_1f707_row3_col4, #T_1f707_row3_col5, #T_1f707_row3_col6, #T_1f707_row3_col7, #T_1f707_row4_col0, #T_1f707_row4_col1, #T_1f707_row4_col2, #T_1f707_row4_col3, #T_1f707_row4_col4, #T_1f707_row4_col5, #T_1f707_row4_col6, #T_1f707_row4_col7, #T_1f707_row5_col0, #T_1f707_row5_col1, #T_1f707_row5_col2, #T_1f707_row5_col3, #T_1f707_row5_col4, #T_1f707_row5_col5, #T_1f707_row5_col6, #T_1f707_row5_col7, #T_1f707_row6_col0, #T_1f707_row6_col1, #T_1f707_row6_col2, #T_1f707_row6_col3, #T_1f707_row6_col4, #T_1f707_row6_col5, #T_1f707_row6_col6, #T_1f707_row6_col7, #T_1f707_row7_col0, #T_1f707_row7_col1, #T_1f707_row7_col2, #T_1f707_row7_col3, #T_1f707_row7_col4, #T_1f707_row7_col5, #T_1f707_row7_col6, #T_1f707_row7_col7, #T_1f707_row8_col0, #T_1f707_row8_col1, #T_1f707_row8_col2, #T_1f707_row8_col3, #T_1f707_row8_col4, #T_1f707_row8_col5, #T_1f707_row8_col6, #T_1f707_row8_col7, #T_1f707_row9_col0, #T_1f707_row9_col1, #T_1f707_row9_col2, #T_1f707_row9_col3, #T_1f707_row9_col4, #T_1f707_row9_col5, #T_1f707_row9_col6, #T_1f707_row9_col7, #T_1f707_row10_col0, #T_1f707_row10_col1, #T_1f707_row10_col2, #T_1f707_row10_col3, #T_1f707_row10_col4, #T_1f707_row10_col5, #T_1f707_row10_col6, #T_1f707_row10_col7, #T_1f707_row11_col0, #T_1f707_row11_col1, #T_1f707_row11_col2, #T_1f707_row11_col3, #T_1f707_row11_col4, #T_1f707_row11_col5, #T_1f707_row11_col6, #T_1f707_row11_col7, #T_1f707_row12_col0, #T_1f707_row12_col1, #T_1f707_row12_col2, #T_1f707_row12_col3, #T_1f707_row12_col5, #T_1f707_row12_col6, #T_1f707_row12_col7, #T_1f707_row13_col0, #T_1f707_row13_col1, #T_1f707_row13_col2, #T_1f707_row13_col3, #T_1f707_row13_col4, #T_1f707_row13_col5, #T_1f707_row13_col6, #T_1f707_row13_col7, #T_1f707_row14_col0, #T_1f707_row14_col1, #T_1f707_row14_col2, #T_1f707_row14_col3, #T_1f707_row14_col4, #T_1f707_row14_col5, #T_1f707_row14_col6, #T_1f707_row14_col7 {
#   text-align: left;
# }
# #T_1f707_row0_col1, #T_1f707_row0_col3, #T_1f707_row0_col5, #T_1f707_row0_col6, #T_1f707_row0_col7, #T_1f707_row1_col2, #T_1f707_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1f707_row0_col8, #T_1f707_row1_col8, #T_1f707_row2_col8, #T_1f707_row3_col8, #T_1f707_row4_col8, #T_1f707_row5_col8, #T_1f707_row6_col8, #T_1f707_row7_col8, #T_1f707_row8_col8, #T_1f707_row9_col8, #T_1f707_row10_col8, #T_1f707_row12_col8, #T_1f707_row13_col8, #T_1f707_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1f707_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1f707">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f707_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1f707_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1f707_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1f707_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1f707_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1f707_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1f707_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1f707_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1f707_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f707_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_1f707_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_1f707_row0_col1" class="data row0 col1" >0.8944</td>
#       <td id="T_1f707_row0_col2" class="data row0 col2" >0.9367</td>
#       <td id="T_1f707_row0_col3" class="data row0 col3" >0.8722</td>
#       <td id="T_1f707_row0_col4" class="data row0 col4" >0.9174</td>
#       <td id="T_1f707_row0_col5" class="data row0 col5" >0.8928</td>
#       <td id="T_1f707_row0_col6" class="data row0 col6" >0.7881</td>
#       <td id="T_1f707_row0_col7" class="data row0 col7" >0.7913</td>
#       <td id="T_1f707_row0_col8" class="data row0 col8" >0.1730</td>
#     </tr>
#     <tr>
#       <th id="T_1f707_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_1f707_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1f707_row1_col1" class="data row1 col1" >0.8775</td>
#       <td id="T_1f707_row1_col2" class="data row1 col2" >0.9464</td>
#       <td id="T_1f707_row1_col3" class="data row1 col3" >0.8458</td>
#       <td id="T_1f707_row1_col4" class="data row1 col4" >0.9206</td>
#       <td id="T_1f707_row1_col5" class="data row1 col5" >0.8741</td>
#       <td id="T_1f707_row1_col6" class="data row1 col6" >0.7523</td>
#       <td id="T_1f707_row1_col7" class="data row1 col7" >0.7651</td>
#       <td id="T_1f707_row1_col8" class="data row1 col8" >0.1920</td>
#     </tr>
#     <tr>
#       <th id="T_1f707_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_1f707_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_1f707_row2_col1" class="data row2 col1" >0.8477</td>
#       <td id="T_1f707_row2_col2" class="data row2 col2" >0.9160</td>
#       <td id="T_1f707_row2_col3" class="data row2 col3" >0.8250</td>
#       <td id="T_1f707_row2_col4" class="data row2 col4" >0.8760</td>
#       <td id="T_1f707_row2_col5" class="data row2 col5" >0.8441</td>
#       <td id="T_1f707_row2_col6" class="data row2 col6" >0.6929</td>
#       <td id="T_1f707_row2_col7" class="data row2 col7" >0.7018</td>
#       <td id="T_1f707_row2_col8" class="data row2 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_1f707_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_1f707_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_1f707_row3_col1" class="data row3 col1" >0.8477</td>
#       <td id="T_1f707_row3_col2" class="data row3 col2" >0.9386</td>
#       <td id="T_1f707_row3_col3" class="data row3 col3" >0.8000</td>
#       <td id="T_1f707_row3_col4" class="data row3 col4" >0.9021</td>
#       <td id="T_1f707_row3_col5" class="data row3 col5" >0.8426</td>
#       <td id="T_1f707_row3_col6" class="data row3 col6" >0.6924</td>
#       <td id="T_1f707_row3_col7" class="data row3 col7" >0.7027</td>
#       <td id="T_1f707_row3_col8" class="data row3 col8" >0.2290</td>
#     </tr>
#     <tr>
#       <th id="T_1f707_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_1f707_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_1f707_row4_col1" class="data row4 col1" >0.8422</td>
#       <td id="T_1f707_row4_col2" class="data row4 col2" >0.9154</td>
#       <td id="T_1f707_row4_col3" class="data row4 col3" >0.7764</td>
#       <td id="T_1f707_row4_col4" class="data row4 col4" >0.9149</td>
#       <td id="T_1f707_row4_col5" class="data row4 col5" >0.8306</td>
#       <td id="T_1f707_row4_col6" class="data row4 col6" >0.6808</td>
#       <td id="T_1f707_row4_col7" class="data row4 col7" >0.6984</td>
#       <td id="T_1f707_row4_col8" class="data row4 col8" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_1f707_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_1f707_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1f707_row5_col1" class="data row5 col1" >0.8310</td>
#       <td id="T_1f707_row5_col2" class="data row5 col2" >0.9190</td>
#       <td id="T_1f707_row5_col3" class="data row5 col3" >0.8125</td>
#       <td id="T_1f707_row5_col4" class="data row5 col4" >0.8663</td>
#       <td i

# %%
best
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
get_metrics(best)
# Out:
#                 Name Display Name  \
# ID
# acc         Accuracy     Accuracy
# auc              AUC          AUC
# recall        Recall       Recall
# precision  Precision        Prec.
# f1                F1           F1
# kappa          Kappa        Kappa
# mcc              MCC          MCC
#
#                                               Score Function  \
# ID
# acc              <function accuracy_score at 0x772606372a20>
# auc        <pycaret.internal.metrics.BinaryMulticlassScor...
# recall     <pycaret.internal.metrics.BinaryMulticlassScor...
# precision  <pycaret.internal.metrics.BinaryMulticlassScor...
# f1         <pycaret.internal.metrics.BinaryMulticlassScor...
# kappa         <function cohen_kappa_score at 0x772606372de0>
# mcc           <function matthews_corrcoef at 0x772606373060>
#
#                                                       Scorer      Target  \
# ID
# acc                                                 accuracy        pred
# auc        make_scorer(roc_auc_score, response_method=('d...  pred_proba
# recall     make_scorer(recall_score, response_method='pre...        pred
# precision  make_scorer(precision_score, response_method='...        pred
# f1         make_scorer(f1_score, response_method='predict...        pred
# kappa      make_scorer(cohen_kappa_score, response_method...        pred
# mcc        make_scorer(matthews_corrcoef, response_method...        pred
#
#                                                     Args  Greater is Better  \
# ID
# acc                                                   {}               True
# auc        {'average': 'weighted', 'multi_class': 'ovr'}               True
# recall                           {'average': 'weighted'}               True
# precision                        {'average': 'weighted'}               True
# f1                               {'average': 'weighted'}               True
# kappa                                                 {}               True
# mcc                                                   {}               True
#
#            Multiclass  Custom
# ID
# acc              True   False
# auc              True   False
# recall           True   False
# precision        True   False
# f1               True   False
# kappa            True   False
# mcc              True   False

# %% [markdown]
# ### Analyzing the Model

# %%
#### Functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ### Visualizing the Best Model

# %%
plot_model(best) #Functional API

# %% [markdown]
# ### Visualizing other components

# %%
attr_dict = {
    'pipeline': "Schematic drawing of the preprocessing pipeline",
    'auc': "Area Under the Curve",
    'threshold': "Discrimination Threshold",
    'pr': "Precision Recall Curve",
    'confusion_matrix': "Confusion Matrix",
    'error': "Class Prediction Error",
    'class_report': "Classification Report",
    'boundary': "Decision Boundary",
    'rfe': "Recursive Feature Selection",
    'learning': "Learning Curve",
    'manifold': "Manifold Learning",
    'calibration': "Calibration Curve",
    'vc': "Validation Curve",
    'dimension': "Dimension Learning",
    'feature': "Feature Importance",
    'feature_all': "Feature Importance (All)",
    'parameter': "Model Hyperparameter",
    'lift': "Lift Curve",
    'gain': "Gain Chart",
    'ks': "KS Statistic Plot",
}

# %%
for key, value in attr_dict.items():
    try:
        print(f"\n===== {value} =====")
        plot_model(best_model, key)
        
    except AttributeError:
        print(f"Oops! Can't plot model for {value}")

# %% [markdown]
# ### Making Prediction

# %%
#### Fnctional API
predictions = predict_model(best)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_65a99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a99_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_65a99_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_65a99_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_65a99_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_65a99_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_65a99_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_65a99_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_65a99_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65a99_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_65a99_row0_col1" class="data row0 col1" >0.9324</td>
#       <td id="T_65a99_row0_col2" class="data row0 col2" >0.9905</td>
#       <td id="T_65a99_row0_col3" class="data row0 col3" >0.8919</td>
#       <td id="T_65a99_row0_col4" class="data row0 col4" >0.9706</td>
#       <td id="T_65a99_row0_col5" class="data row0 col5" >0.9296</td>
#       <td id="T_65a99_row0_col6" class="data row0 col6" >0.8649</td>
#       <td id="T_65a99_row0_col7" class="data row0 col7" >0.8677</td>
#     </tr>
#   </tbody>
# </table>
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 111   42    0        0           1        1        1         0          1
# 110    7    0        1           0        0        0         0          1
# 132   48    0        1           0        1        1         1          1
# 203   61    0        0           0        1        1         0          2
# 130   54    0        1           0        0        0         0          1
#
#      liver_firm  spleen_palpable  ...  varices  bilirubin  alk_phosphate  \
# 111           0                0  ...        0   0.500000      62.000000
# 110           1                1  ...        0   0.700000     256.000000
# 132           1                0  ...        0   2.000000     158.000000
# 203           2                0  ...        0   1.150618     105.325394
# 130           0                0  ...        0   1.000000      85.000000
#
#            sgot   albumin    protime  histology  class  prediction_label  \
# 111   68.000000  3.800000  29.000000          1      0                 0
# 110   25.000000  4.200000  62.280899          1      1                 1
# 132  278.000000  3.800000  62.280899          1      1                 1
# 203   69.122726  3.817266  62.280899          0      0                 0
# 130   30.000000  4.500000   0.000000          1      1                 1
#
#      prediction_score
# 111              0.69
# 110              0.70
# 132              0.51
# 203              0.80
# 130              0.82
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Passing the test data to make predictions

# %%
# ### functional API
# predictions = predict_model(best, data=data)
# predictions.head()

# %% [markdown]
# ### Displaying the probability of both classes

# %%
### Functional API
predictions = predict_model(best, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_29a86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29a86_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_29a86_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_29a86_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_29a86_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_29a86_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_29a86_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_29a86_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_29a86_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29a86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29a86_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_29a86_row0_col1" class="data row0 col1" >0.9324</td>
#       <td id="T_29a86_row0_col2" class="data row0 col2" >0.9905</td>
#       <td id="T_29a86_row0_col3" class="data row0 col3" >0.8919</td>
#       <td id="T_29a86_row0_col4" class="data row0 col4" >0.9706</td>
#       <td id="T_29a86_row0_col5" class="data row0 col5" >0.9296</td>
#       <td id="T_29a86_row0_col6" class="data row0 col6" >0.8649</td>
#       <td id="T_29a86_row0_col7" class="data row0 col7" >0.8677</td>
#     </tr>
#   </tbody>
# </table>
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 111   42    0        0           1        1        1         0          1
# 110    7    0        1           0        0        0         0          1
# 132   48    0        1           0        1        1         1          1
# 203   61    0        0           0        1        1         0          2
# 130   54    0        1           0        0        0         0          1
#
#      liver_firm  spleen_palpable  ...  bilirubin  alk_phosphate        sgot  \
# 111           0                0  ...   0.500000      62.000000   68.000000
# 110           1                1  ...   0.700000     256.000000   25.000000
# 132           1                0  ...   2.000000     158.000000  278.000000
# 203           2                0  ...   1.150618     105.325394   69.122726
# 130           0                0  ...   1.000000      85.000000   30.000000
#
#       albumin    protime  histology  class  prediction_label  \
# 111  3.800000  29.000000          1      0                 0
# 110  4.200000  62.280899          1      1                 1
# 132  3.800000  62.280899          1      1                 1
# 203  3.817266  62.280899          0      0                 0
# 130  4.500000   0.000000          1      1                 1
#
#      prediction_score_0  prediction_score_1
# 111                0.69                0.31
# 110                0.30                0.70
# 132                0.49                0.51
# 203                0.80                0.20
# 130                0.18                0.82
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Saving the Model

# %%
### Functional API
save_model(best, "smote_model")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'sex', 'steroid',
#                                               'antivirals', 'fatigue', 'malaise',
#                                               'anorexia', 'liver_big',
#                                               'liver_firm', 'spleen_palpable',
#                                               'spiders', 'ascites', 'varices',
#                                               'bilirubin', 'alk_phosphate',
#                                               'sgot', 'albumin', 'protime',
#                                               'histology'],
#                                      transformer=SimpleImputer(add_indica...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='sqrt',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        monotonic_cst=None, n_estimators=100,
#                                        n_jobs=-1, oob_score=False,
#                                        random_state=123, verbose=0,
#                                        warm_start=False))],
#           verbose=False),
#  'smote_model.pkl')
